# %% [markdown]
# <a href="https://colab.research.google.com/github/soumik03/Major_Project_Bioinformatics/blob/main/CDD_ML_Part_1_Bioactivity_Data_Concised_Staphylococcus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
#
#
# In this Jupyter notebook, we will be building a real-life **data science project**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
#
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2022; ChEMBL version 29].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.7-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 2.2 MB/s
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (2.23.0)
# Requirement already satisfied: easydict in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (1.24.3)
# Collecting requests-cache~=0.7.0
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Collecting itsdangerous>=2.0.1
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting pyyaml>=5.4
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 11.1 MB/s
# Requirement already satisfied: attrs<22.0,>=21.2 in /usr/local/lib/python3.7/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.4.0)
# Collecting url-normalize<2.0,>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.15.0)
# Installing collected packages: url-normalize, pyyaml, itsdangerous, requests-cache, chembl-webresource-client
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.1.2 which is incompatible.
# Successfully installed chembl-webresource-client-0.10.7 itsdangerous-2.1.2 pyyaml-6.0 requests-cache-0.7.5 url-normalize-1.4.3

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Staphylococcus**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('Staphylococcus')
targets = pd.DataFrame.from_dict(target_query)
#targets.query('organism=="Homo sapiens"')
targets
#targets[targets.organism.str.contains('Homo sapiens')]
# Out:
#     cross_references                                           organism  \
# 0                 []           Staphylococcus aureus (strain NCTC 8325)
# 1                 []                                     Staphylococcus
# 2                 []                              Staphylococcus aureus
# 3                 []                         Staphylococcus epidermidis
# 4                 []                        Staphylococcus haemolyticus
# ..               ...                                                ...
# 118               []  Staphylococcus saprophyticus subsp. saprophyti...
# 119               []                              Staphylococcus aureus
# 120               []                              Staphylococcus aureus
# 121               []                              Staphylococcus aureus
# 122               []                              Staphylococcus aureus
#
#                              pref_name  score  species_group_flag  \
# 0        Histidine protein kinase SaeS   17.0               False
# 1                       Staphylococcus   14.0                True
# 2                Staphylococcus aureus   12.0               False
# 3           Staphylococcus epidermidis   12.0               False
# 4          Staphylococcus haemolyticus   12.0               False
# ..                                 ...    ...                 ...
# 118            Putative nitroreductase    7.0               False
# 119  Teichoic acid D-alanyltransferase    7.0               False
# 120                            Biofilm    7.0               False
# 121                      Peptidoglycan    7.0               False
# 122                Elongation factor G    7.0               False
#
#     target_chembl_id                                  target_components  \
# 0      CHEMBL4295597  [{'accession': 'Q2G2U1', 'component_descriptio...
# 1       CHEMBL612624                                                 []
# 2          CHEMBL352                                                 []
# 3          CHEMBL353                                                 []
# 4       CHEMBL612507                                                 []
# ..               ...                                                ...
# 118    CHEMBL4523956  [{'accession': 'Q4A0P1', 'component_descriptio...
# 119    CHEMBL4524023  [{'accession': 'Q53662', 'component_descriptio...
# 120    CHEMBL4632349                                                 []
# 121    CHEMBL4632350                                                 []
# 122    CHEMBL4665583  [{'accession': 'P68790', 'component_descriptio...
#
#         target_type  tax_id
# 0    SINGLE PROTEIN   93061
# 1          ORGANISM    1279
# 2          ORGANISM    1280
# 3          ORGANISM    1282
# 4          ORGANISM    1283
# ..              ...     ...
# 118  SINGLE PROTEIN  342451
# 119  SINGLE PROTEIN    1280
# 120   MACROMOLECULE    1280
# 121   MACROMOLECULE    1280
# 122  SINGLE PROTEIN    1280
#
# [123 rows x 9 columns]

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Staphylococcus* (second entry)**

# %% [markdown]
# We will assign the second entry (which corresponds to the target protein, *Staphylococcus*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL612624'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Staphylococcus* (CHEMBL612624) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="MIC").filter(standard_units="ug.mL-1")

# %%
df = pd.DataFrame.from_dict(res)

# %%
#i = df[df.standard_units =='nM'].index
#df.drop(i)
df
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0               None       223411                  []    CHEMBL807282
# 1               None       224799                  []    CHEMBL807277
# 2               None       233754                  []    CHEMBL807281
# 3               None       236249                  []    CHEMBL807283
# 4               None       241630                  []    CHEMBL807277
# ..               ...          ...                 ...             ...
# 869             None     15711327                  []   CHEMBL3614411
# 870             None     15711328                  []   CHEMBL3614411
# 871             None     18662241                  []   CHEMBL4232350
# 872             None     19259067                  []   CHEMBL4403633
# 873             None     22482721                  []   CHEMBL4687907
#
#                                      assay_description assay_type  \
# 0    In vitro minimum inhibitory concentration agai...          F
# 1    In vitro minimum inhibitory concentration agai...          F
# 2    In vitro minimum inhibitory concentration agai...          F
# 3    In vitro minimum inhibitory concentration agai...          F
# 4    In vitro minimum inhibitory concentration agai...          F
# ..                                                 ...        ...
# 869  Antimicrobial activity against Staphylococcus ...          F
# 870  Antimicrobial activity against Staphylococcus ...          F
# 871      Antimicrobial activity against Staphylococcus          F
# 872  Antibacterial activity against methicillin-sen...          F
# 873      Antibacterial activity against Staphylococcus          F
#
#     assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                      None                   None  BAO_0002146  BAO_0000218
# 1                      None                   None  BAO_0002146  BAO_0000218
# 2                      None                   None  BAO_0002146  BAO_0000218
# 3                      None                   None  BAO_0002146  BAO_0000218
# 4                      None                   None  BAO_0002146  BAO_0000218
# ..                      ...                    ...          ...          ...
# 869                    None                   None  BAO_0002146  BAO_0000218
# 870                    None                   None  BAO_0002146  BAO_0000218
# 871                    None                   None  BAO_0002146  BAO_0000218
# 872                    None                   None  BAO_0002146  BAO_0000218
# 873                    None                   None  BAO_0000179  BAO_0000218
#
#      ... target_organism target_pref_name target_tax_id text_value  toid type  \
# 0    ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 1    ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 2    ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 3    ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 4    ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# ..   ...             ...              ...           ...        ...   ...  ...
# 869  ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 870  ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 871  ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 872  ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 873  ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
#
#        units    uo_units upper_value  value
# 0    ug ml-1  UO_0000274        None    2.0
# 1    ug ml-1  UO_0000274        None  128.0
# 2    ug ml-1  UO_0000274        None    2.0
# 3    ug ml-1  UO_0000274        None    4.0
# 4    ug ml-1  UO_0000274        None    2.0
# ..       ...         ...         ...    ...
# 869    mg/ml  UO_0000274        None    0.3
# 870    mg/ml  UO_0000274        None    0.6
# 871  ug ml-1  UO_0000274        0.78    0.2
# 872  ug ml-1  UO_0000274        None    1.0
# 873  ug ml-1        None        None  0.125
#
# [874 rows x 45 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('Staphylococcus_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
#i = df2[df2.units == 'nM'].index
#df2.drop(i)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0               None       223411                  []    CHEMBL807282
# 1               None       224799                  []    CHEMBL807277
# 2               None       233754                  []    CHEMBL807281
# 3               None       236249                  []    CHEMBL807283
# 4               None       241630                  []    CHEMBL807277
# ..               ...          ...                 ...             ...
# 869             None     15711327                  []   CHEMBL3614411
# 870             None     15711328                  []   CHEMBL3614411
# 871             None     18662241                  []   CHEMBL4232350
# 872             None     19259067                  []   CHEMBL4403633
# 873             None     22482721                  []   CHEMBL4687907
#
#                                      assay_description assay_type  \
# 0    In vitro minimum inhibitory concentration agai...          F
# 1    In vitro minimum inhibitory concentration agai...          F
# 2    In vitro minimum inhibitory concentration agai...          F
# 3    In vitro minimum inhibitory concentration agai...          F
# 4    In vitro minimum inhibitory concentration agai...          F
# ..                                                 ...        ...
# 869  Antimicrobial activity against Staphylococcus ...          F
# 870  Antimicrobial activity against Staphylococcus ...          F
# 871      Antimicrobial activity against Staphylococcus          F
# 872  Antibacterial activity against methicillin-sen...          F
# 873      Antibacterial activity against Staphylococcus          F
#
#     assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                      None                   None  BAO_0002146  BAO_0000218
# 1                      None                   None  BAO_0002146  BAO_0000218
# 2                      None                   None  BAO_0002146  BAO_0000218
# 3                      None                   None  BAO_0002146  BAO_0000218
# 4                      None                   None  BAO_0002146  BAO_0000218
# ..                      ...                    ...          ...          ...
# 869                    None                   None  BAO_0002146  BAO_0000218
# 870                    None                   None  BAO_0002146  BAO_0000218
# 871                    None                   None  BAO_0002146  BAO_0000218
# 872                    None                   None  BAO_0002146  BAO_0000218
# 873                    None                   None  BAO_0000179  BAO_0000218
#
#      ... target_organism target_pref_name target_tax_id text_value  toid type  \
# 0    ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 1    ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 2    ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 3    ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 4    ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# ..   ...             ...              ...           ...        ...   ...  ...
# 869  ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 870  ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 871  ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 872  ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 873  ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
#
#        units    uo_units upper_value  value
# 0    ug ml-1  UO_0000274        None    2.0
# 1    ug ml-1  UO_0000274        None  128.0
# 2    ug ml-1  UO_0000274        None    2.0
# 3    ug ml-1  UO_0000274        None    4.0
# 4    ug ml-1  UO_0000274        None    2.0
# ..       ...         ...         ...    ...
# 869    mg/ml  UO_0000274        None    0.3
# 870    mg/ml  UO_0000274        None    0.6
# 871  ug ml-1  UO_0000274        0.78    0.2
# 872  ug ml-1  UO_0000274        None    1.0
# 873  ug ml-1        None        None  0.125
#
# [873 rows x 45 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 454

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0               None       223411                  []    CHEMBL807282
# 1               None       224799                  []    CHEMBL807277
# 2               None       233754                  []    CHEMBL807281
# 3               None       236249                  []    CHEMBL807283
# 4               None       241630                  []    CHEMBL807277
# ..               ...          ...                 ...             ...
# 864             None     15234102                  []   CHEMBL3424495
# 865             None     15663494                  []   CHEMBL3599237
# 866             None     15711324                  []   CHEMBL3614411
# 871             None     18662241                  []   CHEMBL4232350
# 872             None     19259067                  []   CHEMBL4403633
#
#                                      assay_description assay_type  \
# 0    In vitro minimum inhibitory concentration agai...          F
# 1    In vitro minimum inhibitory concentration agai...          F
# 2    In vitro minimum inhibitory concentration agai...          F
# 3    In vitro minimum inhibitory concentration agai...          F
# 4    In vitro minimum inhibitory concentration agai...          F
# ..                                                 ...        ...
# 864  Antimicrobial activity against coagulase-negat...          F
# 865       Antimicrobial activity against Staphylococci          F
# 866  Antimicrobial activity against Staphylococcus ...          F
# 871      Antimicrobial activity against Staphylococcus          F
# 872  Antibacterial activity against methicillin-sen...          F
#
#     assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                      None                   None  BAO_0002146  BAO_0000218
# 1                      None                   None  BAO_0002146  BAO_0000218
# 2                      None                   None  BAO_0002146  BAO_0000218
# 3                      None                   None  BAO_0002146  BAO_0000218
# 4                      None                   None  BAO_0002146  BAO_0000218
# ..                      ...                    ...          ...          ...
# 864                    None                   None  BAO_0002146  BAO_0000218
# 865                    None                   None  BAO_0002146  BAO_0000218
# 866                    None                   None  BAO_0002146  BAO_0000218
# 871                    None                   None  BAO_0002146  BAO_0000218
# 872                    None                   None  BAO_0002146  BAO_0000218
#
#      ... target_organism target_pref_name target_tax_id text_value  toid type  \
# 0    ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 1    ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 2    ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 3    ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 4    ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# ..   ...             ...              ...           ...        ...   ...  ...
# 864  ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 865  ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 866  ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 871  ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
# 872  ...  Staphylococcus   Staphylococcus          1279       None  None  MIC
#
#        units    uo_units upper_value  value
# 0    ug ml-1  UO_0000274        None    2.0
# 1    ug ml-1  UO_0000274        None  128.0
# 2    ug ml-1  UO_0000274        None    2.0
# 3    ug ml-1  UO_0000274        None    4.0
# 4    ug ml-1  UO_0000274        None    2.0
# ..       ...         ...         ...    ...
# 864  ug ml-1  UO_0000274        None    1.0
# 865  ug ml-1  UO_0000274        None  0.095
# 866    mg/ml  UO_0000274        None    0.2
# 871  ug ml-1  UO_0000274        0.78    0.2
# 872  ug ml-1  UO_0000274        None    1.0
#
# [454 rows x 45 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL411818  NC1=NC[C@@H]([C@H](O)[C@@H]2NC(=O)[C@@H](Cc3cc...
# 1         CHEMBL415411  C[C@@H](c1ccccc1)C1NC(=O)CNC(=O)[C@H](CO)NC(=O...
# 2         CHEMBL385882  NC1=NC[C@@H]([C@H](O)[C@@H]2NC(=O)[C@@H](Cc3cc...
# 3         CHEMBL558538  C[C@@H](c1ccccc1)C1NC(=O)CNC(=O)[C@H](CO)NC(=O...
# 4         CHEMBL415182  C[C@@H](c1ccccc1)C1NC(=O)CNC(=O)[C@H](CO)NC(=O...
# ..                 ...                                                ...
# 864      CHEMBL1231498  Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)(O)OCCCCC[C...
# 865      CHEMBL2332001  CCN(CC)CCCCOc1cc2oc3cc(OCCCCN(CC)CC)c(OC)c(CC=...
# 866      CHEMBL3612556  Fc1ccc(C2=NN(c3ccccc3)C(c3cn(-c4ccccc4)nc3-c3c...
# 871      CHEMBL4249987                 CCCc1c(O)cc2oc3cc(Cl)cn3c(=O)c2c1O
# 872      CHEMBL1614669         Cn1cc(/C=C2/C(=O)N3C(C(=O)O)=CS[C@H]23)nn1
#
#     standard_value
# 0              2.0
# 1            128.0
# 2              2.0
# 3              4.0
# 4              2.0
# ..             ...
# 864            1.0
# 865          0.095
# 866          200.0
# 871            0.2
# 872            1.0
#
# [454 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('Staphylococcus_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the MIc unit. Compounds having values of less than 1 ug.mL-1 will be considered to be **active** while those greater than 10 ug.mL-1 will be considered to be **inactive**. As for those values in between 1 and 10 ug.mL-1 will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('Staphylococcus_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL411818  NC1=NC[C@@H]([C@H](O)[C@@H]2NC(=O)[C@@H](Cc3cc...
# 1         CHEMBL415411  C[C@@H](c1ccccc1)C1NC(=O)CNC(=O)[C@H](CO)NC(=O...
# 2         CHEMBL385882  NC1=NC[C@@H]([C@H](O)[C@@H]2NC(=O)[C@@H](Cc3cc...
# 3         CHEMBL558538  C[C@@H](c1ccccc1)C1NC(=O)CNC(=O)[C@H](CO)NC(=O...
# 4         CHEMBL415182  C[C@@H](c1ccccc1)C1NC(=O)CNC(=O)[C@H](CO)NC(=O...
# ..                 ...                                                ...
# 449      CHEMBL1231498  Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)(O)OCCCCC[C...
# 450      CHEMBL2332001  CCN(CC)CCCCOc1cc2oc3cc(OCCCCN(CC)CC)c(OC)c(CC=...
# 451      CHEMBL3612556  Fc1ccc(C2=NN(c3ccccc3)C(c3cn(-c4ccccc4)nc3-c3c...
# 452      CHEMBL4249987                 CCCc1c(O)cc2oc3cc(Cl)cn3c(=O)c2c1O
# 453      CHEMBL1614669         Cn1cc(/C=C2/C(=O)N3C(C(=O)O)=CS[C@H]23)nn1
#
#      standard_value         class
# 0             2.000  intermediate
# 1           128.000      inactive
# 2             2.000  intermediate
# 3             4.000  intermediate
# 4             2.000  intermediate
# ..              ...           ...
# 449           1.000        active
# 450           0.095        active
# 451         200.000      inactive
# 452           0.200        active
# 453           1.000        active
#
# [454 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('Staphylococcus_03_bioactivity_data_curated.csv', index=False)

# %%
! zip Staphylococcus.zip *.csv
# Out:
# updating: Staphylococcus_01_bioactivity_data_raw.csv (deflated 95%)
# updating: Staphylococcus_02_bioactivity_data_preprocessed.csv (deflated 87%)
# updating: Staphylococcus_03_bioactivity_data_curated.csv (deflated 88%)

# %%
! ls -l
# Out:
# total 656
# drwxr-xr-x 1 root root   4096 Apr 19 14:23 sample_data
# -rw-r--r-- 1 root root 491979 Apr 21 17:48 Staphylococcus_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  60374 Apr 21 17:49 Staphylococcus_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  64807 Apr 21 17:50 Staphylococcus_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  42141 Apr 21 17:50 Staphylococcus.zip

# %% [markdown]
# ---
