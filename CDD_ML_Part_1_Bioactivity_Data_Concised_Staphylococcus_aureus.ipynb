# %% [markdown]
# <a href="https://colab.research.google.com/github/soumik03/Major_Project_Bioinformatics/blob/main/CDD_ML_Part_1_Bioactivity_Data_Concised_Staphylococcus_aureus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
#
#
# In this Jupyter notebook, we will be building a real-life **data science project**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
#
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2022; ChEMBL version 29].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#      |████████████████████████████████| 55 kB 3.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 45.7 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.1.2 which is incompatible.
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Staphylococcus aureus**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('Staphylococcus aureus')
targets = pd.DataFrame.from_dict(target_query)
#targets.query('organism=="Homo sapiens"')
targets
#targets[targets.organism.str.contains('Homo sapiens')]
# Out:
#    cross_references                                     organism  \
# 0                []                        Staphylococcus aureus
# 1                []          Staphylococcus aureus subsp. aureus
# 2                []      Staphylococcus aureus subsp. aureus MW2
# 3                []  Staphylococcus aureus subsp. aureus MRSA252
# 4                []   Staphylococcus aureus subsp. aureus RN4220
# ..              ...                                          ...
# 84               []                        Staphylococcus aureus
# 85               []                        Staphylococcus aureus
# 86               []                        Staphylococcus aureus
# 87               []                        Staphylococcus aureus
# 88               []                        Staphylococcus aureus
#
#                                             pref_name  score  \
# 0                               Staphylococcus aureus   27.0
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Staphylococcus* (first entry)**

# %% [markdown]
# We will assign the second entry (which corresponds to the target protein, *Staphylococcus*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL352'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Staphylococcus* (CHEMBL612624) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="MIC").filter(standard_units="ug.mL-1")

# %%
df = pd.DataFrame.from_dict(res)

# %%
#i = df[df.standard_units =='nM'].index
#df.drop(i)
df
# Out:
#        activity_comment  activity_id  \
# 0                  None        31972
# 1                  None        32281
# 2                  None        32287
# 3                  None        32421
# 4                  None        32422
# ...                 ...          ...
# 102854             None     22995196
# 102855             None     22995197
# 102856             None     22995198
# 102857             None     22995199
# 102858             None     22995200
#
#                                       activity_properties assay_chembl_id  \
# 0                                                      []    CHEMBL811149
# 1                                                      []    CHEMBL814224
# 2                                                      []    CHEMBL814224
# 3                                                      []    CHEMBL811134
# 4                                                      []    CHEMBL811133
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('Staphylococcus_aureus_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
#i = df2[df2.units == 'nM'].index
#df2.drop(i)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#        activity_comment  activity_id  \
# 0                  None        31972
# 1                  None        32281
# 2                  None        32287
# 3                  None        32421
# 4                  None        32422
# ...                 ...          ...
# 102854             None     22995196
# 102855             None     22995197
# 102856             None     22995198
# 102857             None     22995199
# 102858             None     22995200
#
#                                       activity_properties assay_chembl_id  \
# 0                                                      []    CHEMBL811149
# 1                                                      []    CHEMBL814224
# 2                                                      []    CHEMBL814224
# 3                                                      []    CHEMBL811134
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 42216

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#        activity_comment  activity_id  \
# 0                  None        31972
# 1                  None        32281
# 2                  None        32287
# 3                  None        32421
# 6                  None        32758
# ...                 ...          ...
# 102806             None     22995127
# 102807             None     22995128
# 102808             None     22995129
# 102809             None     22995130
# 102810             None     22995131
#
#                                       activity_properties assay_chembl_id  \
# 0                                                      []    CHEMBL811149
# 1                                                      []    CHEMBL814224
# 2                                                      []    CHEMBL814224
# 3                                                      []    CHEMBL811134
# 6                                                      []    CHEMBL809631
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#        molecule_chembl_id                                   canonical_smiles  \
# 0              CHEMBL1446  NC[C@H]1O[C@H](O[C@@H]2[C@@H](N)C[C@@H](N)[C@H...
# 1             CHEMBL78569  CC[C@H]1OC(=O)[C@H](C)[C@H]2OC3(CCN(C(=O)c4ccc...
# 2            CHEMBL309514  CC[C@H]1OC(=O)[C@H](C)[C@H]2OC3(CCN(C(=O)c4cnc...
# 3             CHEMBL96258  CN1Cc2csc3c(C(=O)O)c(=O)c4cc(F)c(N5CCOC(CF)C5)...
# 6            CHEMBL348223  CC(=O)OC1C(C)C2/C=C/OC3(C)Oc4c(C)c(O)c5c(O)c(c...
# ...                   ...                                                ...
# 102806      CHEMBL4788924  C=C1C[C@]23C=C(Sc4cccs4)C(=O)[C@@](C)(CCC(=O)N...
# 102807      CHEMBL4783073  C=C1C[C@]23C=C(Sc4ccc(I)cc4)C(=O)[C@@](C)(CCC(...
# 102808      CHEMBL4792317  C=C1C[C@]23C=C(SC4CCCCC4)C(=O)[C@@](C)(CCC(=O)...
# 102809      CHEMBL4788159  C=C1C[C@]23C=C(Sc4ccc(C)cc4)C(=O)[C@@](C)(CCC(...
# 102810      CHEMBL4800275  C=C1C[C@@]23CC[C@@H]1C[C@H]2[C@](C)(CCC(=O)Nc1...
#
#        standard_value
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('Staphylococcus_aureus_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the MIc unit. Compounds having values of less than 1 ug.mL-1 will be considered to be **active** while those greater than 10 ug.mL-1 will be considered to be **inactive**. As for those values in between 1 and 10 ug.mL-1 will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('Staphylococcus_aureus_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 0             CHEMBL1446  NC[C@H]1O[C@H](O[C@@H]2[C@@H](N)C[C@@H](N)[C@H...
# 1            CHEMBL78569  CC[C@H]1OC(=O)[C@H](C)[C@H]2OC3(CCN(C(=O)c4ccc...
# 2           CHEMBL309514  CC[C@H]1OC(=O)[C@H](C)[C@H]2OC3(CCN(C(=O)c4cnc...
# 3            CHEMBL96258  CN1Cc2csc3c(C(=O)O)c(=O)c4cc(F)c(N5CCOC(CF)C5)...
# 4           CHEMBL348223  CC(=O)OC1C(C)C2/C=C/OC3(C)Oc4c(C)c(O)c5c(O)c(c...
# ...                  ...                                                ...
# 42211      CHEMBL4788924  C=C1C[C@]23C=C(Sc4cccs4)C(=O)[C@@](C)(CCC(=O)N...
# 42212      CHEMBL4783073  C=C1C[C@]23C=C(Sc4ccc(I)cc4)C(=O)[C@@](C)(CCC(...
# 42213      CHEMBL4792317  C=C1C[C@]23C=C(SC4CCCCC4)C(=O)[C@@](C)(CCC(=O)...
# 42214      CHEMBL4788159  C=C1C[C@]23C=C(Sc4ccc(C)cc4)C(=O)[C@@](C)(CCC(...
# 42215      CHEMBL4800275  C=C1C[C@@]23CC[C@@H]1C[C@H]2[C@](C)(CCC(=O)Nc1...
#
#        standard_value         class
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('Staphylococcus_aureus_03_bioactivity_data_curated.csv', index=False)

# %%
! zip Staphylococcus.zip *.csv
# Out:
# updating: Staphylococcus_01_bioactivity_data_raw.csv (deflated 96%)
# updating: Staphylococcus_02_bioactivity_data_preprocessed.csv (deflated 86%)
# updating: Staphylococcus_03_bioactivity_data_curated.csv (deflated 87%)
#   adding: Staphylococcus_aureus_01_bioactivity_data_raw.csv (deflated 96%)
#   adding: Staphylococcus_aureus_02_bioactivity_data_preprocessed.csv (deflated 86%)
#   adding: Staphylococcus_aureus_03_bioactivity_data_curated.csv (deflated 87%)

# %%
! ls -l
# Out:
# total 133516
# drwxr-xr-x 1 root root     4096 Apr 19 14:23 sample_data
# -rw-r--r-- 1 root root 56072391 Apr 22 20:52 Staphylococcus_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  4117858 Apr 22 20:53 Staphylococcus_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  4518092 Apr 22 20:53 Staphylococcus_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root 56072391 Apr 22 20:55 Staphylococcus_aureus_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  4117858 Apr 22 20:55 Staphylococcus_aureus_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  4518092 Apr 22 20:55 Staphylococcus_aureus_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  7279000 Apr 22 20:55 Staphylococcus.zip

# %% [markdown]
# ---
