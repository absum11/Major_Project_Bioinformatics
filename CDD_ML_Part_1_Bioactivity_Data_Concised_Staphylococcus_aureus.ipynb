# %% [markdown]
# <a href="https://colab.research.google.com/github/soumik03/Major_Project_Bioinformatics/blob/main/CDD_ML_Part_1_Bioactivity_Data_Concised_Staphylococcus_aureus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
#
#
# In this Jupyter notebook, we will be building a real-life **data science project**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
#
#
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2022; ChEMBL version 29].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 2.5 MB/s
# Requirement already satisfied: easydict in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (1.24.3)
# Collecting requests-cache~=0.7.0
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)
# Collecting url-normalize<2.0,>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Collecting itsdangerous>=2.0.1
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs<22.0,>=21.2 in /usr/local/lib/python3.7/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.4.0)
# Collecting pyyaml>=5.4
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 17.3 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.15.0)
# Installing collected packages: url-normalize, pyyaml, itsdangerous, requests-cache, chembl-webresource-client
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.1.2 which is incompatible.
# Successfully installed chembl-webresource-client-0.10.8 itsdangerous-2.1.2 pyyaml-6.0 requests-cache-0.7.5 url-normalize-1.4.3

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Staphylococcus aureus**

# %%
# Target search 
target = new_client.target
target_query = target.search('Staphylococcus aureus')
targets = pd.DataFrame.from_dict(target_query)
targets.query('organism=="Homo sapiens"')
targets
#targets[targets.organism.str.contains('Homo sapiens')]
# Out:
#    cross_references                                     organism  \
# 0                []                        Staphylococcus aureus
# 1                []          Staphylococcus aureus subsp. aureus
# 2                []      Staphylococcus aureus subsp. aureus MW2
# 3                []  Staphylococcus aureus subsp. aureus MRSA252
# 4                []   Staphylococcus aureus subsp. aureus RN4220
# ..              ...                                          ...
# 84               []                        Staphylococcus aureus
# 85               []                        Staphylococcus aureus
# 86               []                        Staphylococcus aureus
# 87               []                        Staphylococcus aureus
# 88               []                        Staphylococcus aureus
#
#                                             pref_name  score  \
# 0                               Staphylococcus aureus   27.0
# 1                 Staphylococcus aureus subsp. aureus   26.0
# 2             Staphylococcus aureus subsp. aureus MW2   24.0
# 3         Staphylococcus aureus subsp. aureus MRSA252   24.0
# 4          Staphylococcus aureus subsp. aureus RN4220   24.0
# ..                                                ...    ...
# 84  Alkaline phosphatase synthesis transcriptional...    8.0
# 85                  Teichoic acid D-alanyltransferase    8.0
# 86                                            Biofilm    8.0
# 87                                      Peptidoglycan    8.0
# 88                                Elongation factor G    8.0
#
#     species_group_flag target_chembl_id  \
# 0                False        CHEMBL352
# 1                False    CHEMBL2366800
# 2                False     CHEMBL612531
# 3                False     CHEMBL612534
# 4                False    CHEMBL2366906
# ..                 ...              ...
# 84               False    CHEMBL4523943
# 85               False    CHEMBL4524023
# 86               False    CHEMBL4632349
# 87               False    CHEMBL4632350
# 88               False    CHEMBL4665583
#
#                                     target_components     target_type  tax_id
# 0                                                  []        ORGANISM    1280
# 1                                                  []        ORGANISM   46170
# 2                                                  []        ORGANISM  196620
# 3                                                  []        ORGANISM  282458
# 4                                                  []        ORGANISM  561307
# ..                                                ...             ...     ...
# 84  [{'accession': 'W8TVM3', 'component_descriptio...  SINGLE PROTEIN    1280
# 85  [{'accession': 'Q53662', 'component_descriptio...  SINGLE PROTEIN    1280
# 86                                                 []   MACROMOLECULE    1280
# 87                                                 []   MACROMOLECULE    1280
# 88  [{'accession': 'P68790', 'component_descriptio...  SINGLE PROTEIN    1280
#
# [89 rows x 9 columns]

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Staphylococcus* (first entry)**

# %% [markdown]
# We will assign the first entry (which corresponds to the target protein, *Staphylococcus aureus* to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL352'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Staphylococcus* (CHEMBL352) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50").filter(standard_units="nM")

# %%
df = pd.DataFrame.from_dict(res)

# %%
#i = df[df.standard_units =='nM'].index
#df.drop(i)
df
# Out:
#      activity_comment  activity_id  \
# 0                None       112064
# 1                None       126079
# 2                None       146501
# 3                None       147668
# 4                None       151231
# ...               ...          ...
# 1183             None     22790165
# 1184             None     22790166
# 1185             None     22790167
# 1186             None     22933744
# 1187             None     22933746
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL805606
# 1                                                    []    CHEMBL802849
# 2                                                    []    CHEMBL858259
# 3                                                    []    CHEMBL858259
# 4                                                    []    CHEMBL858259
# ...                                                 ...             ...
# 1183  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4709341
# 1184  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4709341
# 1185  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4709341
# 1186  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4739103
# 1187  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4739103
#
#                                       assay_description assay_type  \
# 0     In vitro inhibitory concentration against Stap...          F
# 1     In vitro inhibitory concentration against Stap...          F
# 2     Activity against gram-positive Staphylococcus ...          F
# 3     Activity against gram-positive Staphylococcus ...          F
# 4     Activity against gram-positive Staphylococcus ...          F
# ...                                                 ...        ...
# 1183  Antibiofilm activity against methicillin-resis...          F
# 1184  Antibiofilm activity against methicillin-resis...          F
# 1185  Antibiofilm activity against methicillin-resis...          F
# 1186  Antibacterial activity against Staphylococcus ...          F
# 1187  Antibacterial activity against Staphylococcus ...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000218
# 1                       None                   None  BAO_0000190  BAO_0000218
# 2                       None                   None  BAO_0000190  BAO_0000218
# 3                       None                   None  BAO_0000190  BAO_0000218
# 4                       None                   None  BAO_0000190  BAO_0000218
# ...                      ...                    ...          ...          ...
# 1183                    None                   None  BAO_0000179  BAO_0000218
# 1184                    None                   None  BAO_0000179  BAO_0000218
# 1185                    None                   None  BAO_0000179  BAO_0000218
# 1186                    None                   None  BAO_0000179  BAO_0000218
# 1187                    None                   None  BAO_0000179  BAO_0000218
#
#       ...        target_organism       target_pref_name target_tax_id  \
# 0     ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 1     ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 2     ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 3     ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 4     ...  Staphylococcus aureus  Staphylococcus aureus          1280
# ...   ...                    ...                    ...           ...
# 1183  ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 1184  ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 1185  ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 1186  ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 1187  ...  Staphylococcus aureus  Staphylococcus aureus          1280
#
#      text_value  toid        type  units    uo_units upper_value value
# 0          None  None        IC50     nM  UO_0000065        None   8.0
# 1          None  None        IC50     nM  UO_0000065        None  16.0
# 2          None  None  Log 1/IC50   None  UO_0000065        None  3.82
# 3          None  None  Log 1/IC50   None  UO_0000065        None  1.93
# 4          None  None  Log 1/IC50   None  UO_0000065        None  2.32
# ...         ...   ...         ...    ...         ...         ...   ...
# 1183       None  None        IC50     uM        None        None  1.34
# 1184       None  None        IC50     uM        None        None  1.34
# 1185       None  None        IC50     uM        None        None  1.34
# 1186       None  None        IC50     uM        None        None  13.9
# 1187       None  None        IC50     uM        None        None   3.8
#
# [1188 rows x 45 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('Staphylococcus_aureus_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
#i = df2[df2.units == 'nM'].index
#df2.drop(i)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#      activity_comment  activity_id  \
# 0                None       112064
# 1                None       126079
# 2                None       146501
# 3                None       147668
# 4                None       151231
# ...               ...          ...
# 1183             None     22790165
# 1184             None     22790166
# 1185             None     22790167
# 1186             None     22933744
# 1187             None     22933746
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL805606
# 1                                                    []    CHEMBL802849
# 2                                                    []    CHEMBL858259
# 3                                                    []    CHEMBL858259
# 4                                                    []    CHEMBL858259
# ...                                                 ...             ...
# 1183  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4709341
# 1184  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4709341
# 1185  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4709341
# 1186  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4739103
# 1187  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4739103
#
#                                       assay_description assay_type  \
# 0     In vitro inhibitory concentration against Stap...          F
# 1     In vitro inhibitory concentration against Stap...          F
# 2     Activity against gram-positive Staphylococcus ...          F
# 3     Activity against gram-positive Staphylococcus ...          F
# 4     Activity against gram-positive Staphylococcus ...          F
# ...                                                 ...        ...
# 1183  Antibiofilm activity against methicillin-resis...          F
# 1184  Antibiofilm activity against methicillin-resis...          F
# 1185  Antibiofilm activity against methicillin-resis...          F
# 1186  Antibacterial activity against Staphylococcus ...          F
# 1187  Antibacterial activity against Staphylococcus ...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000218
# 1                       None                   None  BAO_0000190  BAO_0000218
# 2                       None                   None  BAO_0000190  BAO_0000218
# 3                       None                   None  BAO_0000190  BAO_0000218
# 4                       None                   None  BAO_0000190  BAO_0000218
# ...                      ...                    ...          ...          ...
# 1183                    None                   None  BAO_0000179  BAO_0000218
# 1184                    None                   None  BAO_0000179  BAO_0000218
# 1185                    None                   None  BAO_0000179  BAO_0000218
# 1186                    None                   None  BAO_0000179  BAO_0000218
# 1187                    None                   None  BAO_0000179  BAO_0000218
#
#       ...        target_organism       target_pref_name target_tax_id  \
# 0     ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 1     ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 2     ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 3     ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 4     ...  Staphylococcus aureus  Staphylococcus aureus          1280
# ...   ...                    ...                    ...           ...
# 1183  ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 1184  ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 1185  ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 1186  ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 1187  ...  Staphylococcus aureus  Staphylococcus aureus          1280
#
#      text_value  toid        type  units    uo_units upper_value value
# 0          None  None        IC50     nM  UO_0000065        None   8.0
# 1          None  None        IC50     nM  UO_0000065        None  16.0
# 2          None  None  Log 1/IC50   None  UO_0000065        None  3.82
# 3          None  None  Log 1/IC50   None  UO_0000065        None  1.93
# 4          None  None  Log 1/IC50   None  UO_0000065        None  2.32
# ...         ...   ...         ...    ...         ...         ...   ...
# 1183       None  None        IC50     uM        None        None  1.34
# 1184       None  None        IC50     uM        None        None  1.34
# 1185       None  None        IC50     uM        None        None  1.34
# 1186       None  None        IC50     uM        None        None  13.9
# 1187       None  None        IC50     uM        None        None   3.8
#
# [1183 rows x 45 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 896

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#      activity_comment  activity_id  \
# 0                None       112064
# 1                None       126079
# 2                None       146501
# 3                None       147668
# 4                None       151231
# ...               ...          ...
# 1182             None     22790164
# 1183             None     22790165
# 1184             None     22790166
# 1185             None     22790167
# 1186             None     22933744
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL805606
# 1                                                    []    CHEMBL802849
# 2                                                    []    CHEMBL858259
# 3                                                    []    CHEMBL858259
# 4                                                    []    CHEMBL858259
# ...                                                 ...             ...
# 1182  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4709341
# 1183  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4709341
# 1184  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4709341
# 1185  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4709341
# 1186  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4739103
#
#                                       assay_description assay_type  \
# 0     In vitro inhibitory concentration against Stap...          F
# 1     In vitro inhibitory concentration against Stap...          F
# 2     Activity against gram-positive Staphylococcus ...          F
# 3     Activity against gram-positive Staphylococcus ...          F
# 4     Activity against gram-positive Staphylococcus ...          F
# ...                                                 ...        ...
# 1182  Antibiofilm activity against methicillin-resis...          F
# 1183  Antibiofilm activity against methicillin-resis...          F
# 1184  Antibiofilm activity against methicillin-resis...          F
# 1185  Antibiofilm activity against methicillin-resis...          F
# 1186  Antibacterial activity against Staphylococcus ...          F
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000218
# 1                       None                   None  BAO_0000190  BAO_0000218
# 2                       None                   None  BAO_0000190  BAO_0000218
# 3                       None                   None  BAO_0000190  BAO_0000218
# 4                       None                   None  BAO_0000190  BAO_0000218
# ...                      ...                    ...          ...          ...
# 1182                    None                   None  BAO_0000179  BAO_0000218
# 1183                    None                   None  BAO_0000179  BAO_0000218
# 1184                    None                   None  BAO_0000179  BAO_0000218
# 1185                    None                   None  BAO_0000179  BAO_0000218
# 1186                    None                   None  BAO_0000179  BAO_0000218
#
#       ...        target_organism       target_pref_name target_tax_id  \
# 0     ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 1     ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 2     ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 3     ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 4     ...  Staphylococcus aureus  Staphylococcus aureus          1280
# ...   ...                    ...                    ...           ...
# 1182  ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 1183  ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 1184  ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 1185  ...  Staphylococcus aureus  Staphylococcus aureus          1280
# 1186  ...  Staphylococcus aureus  Staphylococcus aureus          1280
#
#      text_value  toid        type  units    uo_units upper_value value
# 0          None  None        IC50     nM  UO_0000065        None   8.0
# 1          None  None        IC50     nM  UO_0000065        None  16.0
# 2          None  None  Log 1/IC50   None  UO_0000065        None  3.82
# 3          None  None  Log 1/IC50   None  UO_0000065        None  1.93
# 4          None  None  Log 1/IC50   None  UO_0000065        None  2.32
# ...         ...   ...         ...    ...         ...         ...   ...
# 1182       None  None        IC50     uM        None        None  1.34
# 1183       None  None        IC50     uM        None        None  1.34
# 1184       None  None        IC50     uM        None        None  1.34
# 1185       None  None        IC50     uM        None        None  1.34
# 1186       None  None        IC50     uM        None        None  13.9
#
# [896 rows x 45 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL304237       Oc1cc(NCCCNC2CCNc3c(Br)cc(Br)cc32)nc2ccccc12
# 1           CHEMBL60402        O=c1cc(NCCCNCc2ccc(Cl)c(Cl)c2)[nH]c2ccccc12
# 2          CHEMBL122734   COc1ccc2c(c1)C(=O)/C(=C/c1ccc([N+](=O)[O-])o1)O2
# 3          CHEMBL122837       O=C(/C=C/c1ccc([N+](=O)[O-])o1)c1cc(Cl)ccc1O
# 4          CHEMBL331082  CC(=O)Oc1ccc(C)cc1C(=O)/C=C/c1ccc([N+](=O)[O-])o1
# ...                 ...                                                ...
# 1182      CHEMBL4745545  C/C(=C/c1ccccc1)Cn1cc(CCCCCc2nc(N)[nH]c2-c2ccc...
# 1183      CHEMBL4785353  C/C(=C/c1ccccc1)Cn1cc(CCCCCc2nc(N)[nH]c2-c2cc(...
# 1184      CHEMBL4779057  C/C(=C/c1ccccc1)Cn1cc(CCCCCc2nc(N)[nH]c2-c2ccc...
# 1185      CHEMBL4757594  C/C(=C/c1ccccc1)Cn1cc(CCCCCc2nc(N)[nH]c2-c2ccc...
# 1186      CHEMBL4752665  COc1cc(/C=C\C(=O)NCCCNCc2cccc(CNCCCNC(=O)/C=C\...
#
#      standard_value
# 0               8.0
# 1              16.0
# 2         151356.12
# 3       11748975.55
# 4        4786300.92
# ...             ...
# 1182         1340.0
# 1183         1340.0
# 1184         1340.0
# 1185         1340.0
# 1186        13900.0
#
# [896 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('Staphylococcus_aureus_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 will be considered to be **active** while those greater than 10000 will be considered to be **inactive**. As for those values in between will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('Staphylococcus_aureus_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL304237       Oc1cc(NCCCNC2CCNc3c(Br)cc(Br)cc32)nc2ccccc12
# 1          CHEMBL60402        O=c1cc(NCCCNCc2ccc(Cl)c(Cl)c2)[nH]c2ccccc12
# 2         CHEMBL122734   COc1ccc2c(c1)C(=O)/C(=C/c1ccc([N+](=O)[O-])o1)O2
# 3         CHEMBL122837       O=C(/C=C/c1ccc([N+](=O)[O-])o1)c1cc(Cl)ccc1O
# 4         CHEMBL331082  CC(=O)Oc1ccc(C)cc1C(=O)/C=C/c1ccc([N+](=O)[O-])o1
# ..                 ...                                                ...
# 891      CHEMBL4745545  C/C(=C/c1ccccc1)Cn1cc(CCCCCc2nc(N)[nH]c2-c2ccc...
# 892      CHEMBL4785353  C/C(=C/c1ccccc1)Cn1cc(CCCCCc2nc(N)[nH]c2-c2cc(...
# 893      CHEMBL4779057  C/C(=C/c1ccccc1)Cn1cc(CCCCCc2nc(N)[nH]c2-c2ccc...
# 894      CHEMBL4757594  C/C(=C/c1ccccc1)Cn1cc(CCCCCc2nc(N)[nH]c2-c2ccc...
# 895      CHEMBL4752665  COc1cc(/C=C\C(=O)NCCCNCc2cccc(CNCCCNC(=O)/C=C\...
#
#      standard_value         class
# 0              8.00        active
# 1             16.00        active
# 2         151356.12      inactive
# 3       11748975.55      inactive
# 4        4786300.92      inactive
# ..              ...           ...
# 891         1340.00  intermediate
# 892         1340.00  intermediate
# 893         1340.00  intermediate
# 894         1340.00  intermediate
# 895        13900.00      inactive
#
# [896 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('Staphylococcus_aureus_03_bioactivity_data_curated.csv', index=False)

# %%
! zip Staphylococcus.zip *.csv
# Out:
#   adding: Staphylococcus_aureus_01_bioactivity_data_raw.csv (deflated 93%)
#   adding: Staphylococcus_aureus_02_bioactivity_data_preprocessed.csv (deflated 81%)
#   adding: Staphylococcus_aureus_03_bioactivity_data_curated.csv (deflated 82%)

# %%
! ls -l
# Out:
# total 852
# drwxr-xr-x 1 root root   4096 Apr 25 13:46 sample_data
# -rw-r--r-- 1 root root 624235 Apr 29 09:50 Staphylococcus_aureus_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  75807 Apr 29 09:50 Staphylococcus_aureus_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  84151 Apr 29 09:52 Staphylococcus_aureus_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  76769 Apr 29 09:52 Staphylococcus.zip

# %% [markdown]
# ---
